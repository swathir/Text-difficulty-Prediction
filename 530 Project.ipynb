# %%
the familiarity of semantic units (words or phrases)
the complexity of syntax
###0.removing from all models any types occurring less than 3 times in the entire corpus
0.remove stop words
All prediction methods used a 100-token window size.
1.UNK: The fraction of ‘unknown’ tokens in the text, relative to the Dale 3000 word list. This is the semantic variable of the Revised Dale-Chall measure.
2.TYPES: The number of types (unique words) in a 100-token passage.
3.MLF: The mean log frequency of the passage relative to a large English corpus.
4.the Flesch-Kincaid score : linear combination of the text’s average sentence length (in tokens), and the average number of syllables per token.

# %%
stop_data = set(['', 'secondly', 'all', 'consider', 'whoever', 'four', 'edu', 'go', 'causes', 'seemed', 'rd', 'certainly', 'vs', 'to', 'asking', 'th', 'under', 'sorry', "a's", 'sent', '@', 'far', 'every', 'yourselves', '`', "we'll", 'went', 'did', 'forth', "they've", 'try', 'p', "it'll", "i'll", 'says', "you'd", 'yourself', 'likely', 'further', 'quite', 'even', 'what', 'appear', 'brief', 'goes', 'sup', 'new', ';', 'ever', "c'mon", 'whose', 'respectively', 'never', 'here', 'let', 'others', "hadn't", 'along', "aren't", 'k', 'allows', "i'd", 'howbeit', 'usually', 'whereupon', "i'm", 'changes', 'thats', 'hither', 'via', 'followed', 'merely', 'while', 'viz', 'everybody', 'use', 'from', 'would', 'contains', 'two', 'next', 'few', 'therefore', 'taken', 'themselves', 'thru', 'tell', 'more', '``', 'knows', 'becomes', 'hereby', 'herein', "ain't", 'particular', 'known', 'must', 'me', 'none', 'f', 'this', 'oh', 'anywhere', 'nine', 'can', 'theirs', 'following', 'my', 'example', 'indicated', "didn't", 'indicates', 'something', 'want', 'needs', 'rather', 'meanwhile', 'how', 'instead', 'okay', 'tried', 'may', 'after', 'different', 'hereupon', 'such', 'a', 'third', 'whenever', 'maybe', 'appreciate', 'q', ')', 'ones', 'so', 'specifying', 'allow', 'keeps', "that's", 'six', 'help', "don't", 'indeed', 'over', 'mainly', 'soon', 'course', 'through', 'looks', 'still', 'its', 'before', 'thank', "he's", 'selves', 'inward', ',', 'actually', 'better', 'whether', 'willing', 'thanx', 'ours', 'might', '<', "haven't", 'then', 'non', 'someone', 'somebody', 'thereby', "you've", 'they', 'not', 'now', 'nor', 'several', 'hereafter', 'always', 'reasonably', 'whither', 'l', 'each', 'entirely', "isn't", 'mean', 'everyone', 'doing', 'eg', 'ex', 'our', 'beyond', 'out', 'them', 'furthermore', 'since', 'looking', 're', 'seriously', "shouldn't", "they'll", 'got', 'cause', 'thereupon', "you're", 'given', 'like', 'que', 'besides', 'x', 'ask', 'anyhow', 'g', 'could', 'tries', 'keep', 'w', 'ltd', 'hence', 'onto', 'think', 'first', 'already', 'seeming', 'thereafter', 'one', 'done', 'another', 'awfully', "doesn't", 'little', 'their', 'accordingly', 'least', 'name', 'anyone', 'indicate', 'too', 'gives', 'mostly', 'behind', 'nobody', 'took', 'immediate', 'regards', 'somewhat', 'off', 'believe', 'herself', 'than', "here's", 'b', 'unfortunately', 'gotten', 'second', 'i', 'r', 'were', 'toward', 'are', 'and', 'beforehand', 'say', 'unlikely', 'have', 'need', 'seen', 'seem', 'saw', 'any', 'relatively', 'zero', 'thoroughly', 'latter', 'that', 'downwards', 'aside', 'thorough', 'also', 'take', 'which', 'exactly', 'unless', 'shall', 'who', "where's", 'most', 'eight', 'but', 'nothing', 'why', 'sub', 'especially', 'noone', 'later', 'm', 'yours', "you'll", 'definitely', 'normally', 'came', 'saying', 'particularly', 'anyway', 'fifth', '(', 'outside', 'should', 'only', 'going', 'specify', 'do', 'his', 'above', 'get', 'between', 'overall', 'truly', "they'd", 'cannot', 'nearly', 'despite', 'during', 'him', 'regarding', 'qv', 'h', 'twice', 'she', 'contain', "won't", 'where', 'thanks', 'ignored', 'up', 'namely', 'anyways', 'best', 'wonder', 'said', 'away', 'currently', 'please', 'enough', "there's", 'various', 'hopefully', 'probably', 'neither', 'across', 'available', 'we', 'useful', 'however', 'come', 'both', 'c', 'last', 'many', "wouldn't", 'thence', 'according', 'against', 'etc', 's', 'became', 'com', "can't", 'otherwise', 'among', 'liked', 'co', 'afterwards', 'seems', 'whatever', 'alone', "couldn't", 'moreover', 'throughout', 'considering', 'sensible', 'described', "it's", 'three', 'been', '.', 'whom', 'much', 'wherein', 'hardly', "it'd", '>', 'wants', 'corresponding', 'latterly', 'concerning', 'else', 'hers', 'former', 'those', 'myself', 'novel', 'look', 'these', 'value', 'n', 'will', 'near', 'theres', 'seven', 'whereafter', 'almost', 'wherever', 'is', 'thus', 'it', 'cant', 'itself', 'in', 'ie', 'y', 'if', 'containing', 'perhaps', 'insofar', 'same', 'clearly', 'beside', 'when', 'gets', "weren't", 'used', 'see', 'somewhere', 'upon', 'uses', 'kept', 'whereby', 'nevertheless', 'whole', 'well', 'anybody', 'obviously', 'without', 'comes', 'very', 'the', 'self', 'lest', 'just', 'less', 'being', 'able', 'presumably', 'greetings', 'regardless', 'yes', 'yet', 'unto', '$', "we've", 'had', 'except', 'has', 'ought', "t's", 'around', "who's", 'possible', 'five', 'know', 'using', 'apart', 'necessary', 'd', 'follows', 'either', 'become', 'towards', 'therein', 'because', 'old', 'often', 'some', 'somehow', 'sure', 'specified', 'ourselves', 'happens', 'for', 'though', 'per', 'everything', 'does', 'provides', 'tends', 't', 'be', 'nowhere', 'although', 'by', 'on', 'about', 'ok', 'anything', 'getting', 'of', 'v', 'o', 'whence', 'plus', 'consequently', 'or', 'seeing', 'own', 'formerly', 'into', 'within', 'down', 'appropriate', 'right', "c's", 'your', 'her', 'there', 'inasmuch', 'inner', 'way', ':', 'was', 'himself', 'elsewhere', "i've", 'becoming', 'amongst', 'hi', 'trying', 'with', 'he', "they're", "wasn't", 'wish', 'j', "hasn't", 'us', 'until', 'placed', 'below', 'un', 'z', "we'd", 'gone', 'sometimes', 'associated', 'certain', 'am', 'an', 'as', 'sometime', 'at', 'et', 'inc', 'again', 'uucp', '%', 'no', 'whereas', 'nd', 'lately', 'other', 'you', 'really', "what's", "'s", 'welcome', "let's", 'serious', 'e', 'together', 'having', 'u', "we're", 'everywhere', 'hello', 'once'])
riage', 'stories', 'woke', 'cake', 'piece', 'pin', 'mask', 'circus', 'pie', 'pig', 'inn', 'goodness', 'ink', 'partly', 'pit', 'happen', 'squirrel', 'pussycat', 'accident ', 'coffeepot', 'book', 'boom', 'branch', 'out', "you're", 'dresser', 'February', 'repeat', 'star', 'again ', 'bundle', 'stay', 'April', 'chance', 'squeak', 'cliff', 'baker', 'rule', 'pupil', 'misspell', 'lives', 'yell', 'sash'])
frequency_model = Counter(['all','graft','defect'])
frac_freq = sum(1 for key,value in frequency_model.items() if key in stop_data)

vocab_size = len(frequency_model)
frac_freq = frac_freq / float(vocab_size)
print frac_freq
# Out:
# 0.333333333333

# %%
import nltk

text = nltk.word_tokenize("NO is a pleiotropic signaling molecule and has an important role in cognition and emotion. In the brain, NO is produced by neuronal nitric oxide synthase (NOS-I, encoded by NOS1) coupled to the NMDA receptor via PDZ interactions; this protein-protein interaction is disrupted upon binding of NOS1 adapter protein (encoded by NOS1AP) to NOS-I. As both NOS1 and NOS1AP were associated with schizophrenia, we here investigated these genes in greater detail by genotyping new samples and conducting a meta-analysis of our own and published data. In doing so, we confirmed association of both genes with schizophrenia and found evidence for their interaction in increasing risk towards disease. Our strongest finding was the NOS1 promoter SNP rs41279104, yielding an odds ratio of 1.29 in the meta-analysis. As findings from heterologous cell systems have suggested that the risk allele decreases gene expression, we studied the effect of the variant on NOS1 expression in human post-mortem brain samples and found that the risk allele significantly decreases expression of NOS1 in the prefrontal cortex. Bioinformatic analyses suggest that this might be due the replacement of six transcription factor binding sites by two new binding sites as a consequence of proxy SNPs. Taken together, our data argue that genetic variance in NOS1 resulting in lower prefrontal brain expression of this gene contributes to schizophrenia liability, and that NOS1 interacts with NOS1AP in doing so. The NOS1-NOS1AP PDZ interface may thus well constitute a novel target for small molecules in at least some forms of schizophrenia.")
nouns = 0
for (f,s) in nltk.pos_tag(text):
    #print s
    if(s == "NN" or s == "NNP"):
        nouns+=1
print nouns/float(len(text))
# Out:
# 0.264705882353

# %%
##########ONLY TRAIN
from nltk import sent_tokenize,word_tokenize
import subprocess
from collections import defaultdict, Counter
import os
import math
import string

# 1-6 type_str, vocab_size,frac_freq,frac_rare,median_word, average_word,frac_nyt))
# 7 Flesch-kincaid
# 8 unk/total (Dale)
# 9 ppl

stop_data = set(['', 'secondly', 'all', 'consider', 'whoever', 'four', 'edu', 'go', 'causes', 'seemed', 'rd', 'certainly', 'vs', 'to', 'asking', 'th', 'under', 'sorry', "a's", 'sent', '@', 'far', 'every', 'yourselves', '`', "we'll", 'went', 'did', 'forth', "they've", 'try', 'p', "it'll", "i'll", 'says', "you'd", 'yourself', 'likely', 'further', 'quite', 'even', 'what', 'appear', 'brief', 'goes', 'sup', 'new', ';', 'ever', "c'mon", 'whose', 'respectively', 'never', 'here', 'let', 'others', "hadn't", 'along', "aren't", 'k', 'allows', "i'd", 'howbeit', 'usually', 'whereupon', "i'm", 'changes', 'thats', 'hither', 'via', 'followed', 'merely', 'while', 'viz', 'everybody', 'use', 'from', 'would', 'contains', 'two', 'next', 'few', 'therefore', 'taken', 'themselves', 'thru', 'tell', 'more', '``', 'knows', 'becomes', 'hereby', 'herein', "ain't", 'particular', 'known', 'must', 'me', 'none', 'f', 'this', 'oh', 'anywhere', 'nine', 'can', 'theirs', 'following', 'my', 'example', 'indicated', "didn't", 'indicates', 'something', 'want', 'needs', 'rather', 'meanwhile', 'how', 'instead', 'okay', 'tried', 'may', 'after', 'different', 'hereupon', 'such', 'a', 'third', 'whenever', 'maybe', 'appreciate', 'q', ')', 'ones', 'so', 'specifying', 'allow', 'keeps', "that's", 'six', 'help', "don't", 'indeed', 'over', 'mainly', 'soon', 'course', 'through', 'looks', 'still', 'its', 'before', 'thank', "he's", 'selves', 'inward', ',', 'actually', 'better', 'whether', 'willing', 'thanx', 'ours', 'might', '<', "haven't", 'then', 'non', 'someone', 'somebody', 'thereby', "you've", 'they', 'not', 'now', 'nor', 'several', 'hereafter', 'always', 'reasonably', 'whither', 'l', 'each', 'entirely', "isn't", 'mean', 'everyone', 'doing', 'eg', 'ex', 'our', 'beyond', 'out', 'them', 'furthermore', 'since', 'looking', 're', 'seriously', "shouldn't", "they'll", 'got', 'cause', 'thereupon', "you're", 'given', 'like', 'que', 'besides', 'x', 'ask', 'anyhow', 'g', 'could', 'tries', 'keep', 'w', 'ltd', 'hence', 'onto', 'think', 'first', 'already', 'seeming', 'thereafter', 'one', 'done', 'another', 'awfully', "doesn't", 'little', 'their', 'accordingly', 'least', 'name', 'anyone', 'indicate', 'too', 'gives', 'mostly', 'behind', 'nobody', 'took', 'immediate', 'regards', 'somewhat', 'off', 'believe', 'herself', 'than', "here's", 'b', 'unfortunately', 'gotten', 'second', 'i', 'r', 'were', 'toward', 'are', 'and', 'beforehand', 'say', 'unlikely', 'have', 'need', 'seen', 'seem', 'saw', 'any', 'relatively', 'zero', 'thoroughly', 'latter', 'that', 'downwards', 'aside', 'thorough', 'also', 'take', 'which', 'exactly', 'unless', 'shall', 'who', "where's", 'most', 'eight', 'but', 'nothing', 'why', 'sub', 'especially', 'noone', 'later', 'm', 'yours', "you'll", 'definitely', 'normally', 'came', 'saying', 'particularly', 'anyway', 'fifth', '(', 'outside', 'should', 'only', 'going', 'specify', 'do', 'his', 'above', 'get', 'between', 'overall', 'truly', "they'd", 'cannot', 'nearly', 'despite', 'during', 'him', 'regarding', 'qv', 'h', 'twice', 'she', 'contain', "won't", 'where', 'thanks', 'ignored', 'up', 'namely', 'anyways', 'best', 'wonder', 'said', 'away', 'currently', 'please', 'enough', "there's", 'various', 'hopefully', 'probably', 'neither', 'across', 'available', 'we', 'useful', 'however', 'come', 'both', 'c', 'last', 'many', "wouldn't", 'thence', 'according', 'against', 'etc', 's', 'became', 'com', "can't", 'otherwise', 'among', 'liked', 'co', 'afterwards', 'seems', 'whatever', 'alone', "couldn't", 'moreover', 'throughout', 'considering', 'sensible', 'described', "it's", 'three', 'been', '.', 'whom', 'much', 'wherein', 'hardly', "it'd", '>', 'wants', 'corresponding', 'latterly', 'concerning', 'else', 'hers', 'former', 'those', 'myself', 'novel', 'look', 'these', 'value', 'n', 'will', 'near', 'theres', 'seven', 'whereafter', 'almost', 'wherever', 'is', 'thus', 'it', 'cant', 'itself', 'in', 'ie', 'y', 'if', 'containing', 'perhaps', 'insofar', 'same', 'clearly', 'beside', 'when', 'gets', "weren't", 'used', 'see', 'somewhere', 'upon', 'uses', 'kept', 'whereby', 'nevertheless', 'whole', 'well', 'anybody', 'obviously', 'without', 'comes', 'very', 'the', 'self', 'lest', 'just', 'less', 'being', 'able', 'presumably', 'greetings', 'regardless', 'yes', 'yet', 'unto', '$', "we've", 'had', 'except', 'has', 'ought', "t's", 'around', "who's", 'possible', 'five', 'know', 'using', 'apart', 'necessary', 'd', 'follows', 'either', 'become', 'towards', 'therein', 'because', 'old', 'often', 'some', 'somehow', 'sure', 'specified', 'ourselves', 'happens', 'for', 'though', 'per', 'everything', 'does', 'provides', 'tends', 't', 'be', 'nowhere', 'although', 'by', 'on', 'about', 'ok', 'anything', 'getting', 'of', 'v', 'o', 'whence', 'plus', 'consequently', 'or', 'seeing', 'own', 'formerly', 'into', 'within', 'down', 'appropriate', 'right', "c's", 'your', 'her', 'there', 'inasmuch', 'inner', 'way', ':', 'was', 'himself', 'elsewhere', "i've", 'becoming', 'amongst', 'hi', 'trying', 'with', 'he', "they're", "wasn't", 'wish', 'j', "hasn't", 'us', 'until', 'placed', 'below', 'un', 'z', "we'd", 'gone', 'sometimes', 'associated', 'certain', 'am', 'an', 'as', 'sometime', 'at', 'et', 'inc', 'again', 'uucp', '%', 'no', 'whereas', 'nd', 'lately', 'other', 'you', 'really', "what's", "'s", 'welcome', "let's", 'serious', 'e', 'together', 'having', 'u', "we're", 'everywhere', 'hello', 'once'])
dale_data = set(['pardon', 'yellow', 'hitch', 'four', 'woods', 'sleep', 'captain', 'hate', 'yonder', 'lace', 'trolley', 'whose', 'electricity', 'swan', 'tickle', 'swat', 'teaspoon', 'under', 'lord', 'sorry', 'chill', 'worth', 'tame', 'blanket', 'rise', 'vase', 'shoot', 'smack', 'every', 'govern', 'fireplace', 'school', 'baking', 'prize', 'buttonhole', 'clothes', 'enjoy', 'chew', 'bicycle', 'quilt', 'clover', 'bacon', 'direct', 'horn', 'nail', 'likely', 'street', 'summer', 'writing', 'shining', 'blue', 'hide', 'pace', 'thunder', 'cooking', 'near', 'liberty', 'sung', 'aged ', 'new', 'net', 'ever', 'told', 'hero', 'men', 'drew', 'herd', 'met', 'mew', 'bookcase', 'china', 'hers', 'path', "aren't", 'dry', 'daughter', 'study', 'cupful', 'robin', 'swam', 'far-off', 'smoke', 'lonesome', 'golden', 'divide', 'straw', 'godmother', 'strap', 'brought', 'ninety', 'glance', 'overhear', 'ore', 'spoke', 'would', 'army', 'hospital', 'June', 'insult', 'call', 'until', 'spike', 'blueberry', 'calf', 'breathe', 'holy', 'hurt', 'warn', 'glass', 'wildcat', 'warm', 'smile', 'hole', 'hold', 'blindfold', 'must', 'me', 'join', 'room', 'shame', 
 'steer', 'perhaps', 'began', 'cross', 'member', 'wicked', 'when', 'strange', 'speaker', 'flour', 'inch', 'party', 'fill', 'ball', 'slave', 'drink', 'upon', 'beast', 'absent ', 'grandstand', 'painful', 'dust', 'overalls', 'collar', 'single', 'off', 'center', 'fully', 'weapon', 'well', 'thought', 'drawing', 'cried', 'flesh', 'boot', 'wren', 'loaf', 'front', 'Sunday', 'glue', 'lettuce', 'happiness', 'flashlight', 'web', 'wee', 'tight', 'Friday', 'sky', 'gum', 'bench', 'other', 'crack', 'ought', 'ski', 'kick', 'oar', 'knob', 'sick', 'government', "who's", 'haul', 'five', 'know', 'knot', 'desk', 'tick', "who'd", 'name', 'loss', 'helpful', 'lost', 'sofa', 'candy', 'garage', 'sissy', 'lose', 'become', 'soft', 'page', 'heel', 'shed', 'because', 'tumble', 'village', 'junk', 'hail', 'hair', 'alike ', 'proper', 'home', 'liking', "shan't", 'leaf', 'lead', 'broad', 'kettle', 'lean', 'shone', 'leap', 'campfire', 'fisherman', 'leader', 'season', 'pepper', 'hose', 'obey', 'pear', 'mitt', 'peas', 'host', 'stormy', 'paste', 'swept', 'noisy', 'throne', 'about', 'getting', 'column', 'freedom', 'biscuit', 'flake', 'swear', 'toadstool', 'blackness', 'cranberry', 'tongue', 'upward', 'swimming', 'owl', 'own', 'owe', 'payment', 'tag', 'socks', 'cocoa', 'guard', 'weather', 'promise', 'brush', 'custard', 'rowboat', 'rejoice', 'scrap', 'whom', 'buckle', 'soil', 'watchman', 'visitor', 'November', 'ivory', 'buy', 'north', 'catsup', 'bus', 'but', 'bun', 'ho', 'bum', 'good-bye', 'ha', 'eat', 'bud', 'he', 'count', 'misty', 'made', 'wise', 'glory', 'dangerous', 'smooth', 'flip', 'nightgown', 'pansy', 'record', 'carriage', 'stories', 'woke', 'cake', 'piece', 'pin', 'mask', 'circus', 'pie', 'pig', 'inn', 'goodness', 'ink', 'partly', 'pit', 'happen', 'squirrel', 'pussycat', 'accident ', 'coffeepot', 'book', 'boom', 'branch', 'out', "you're", 'dresser', 'February', 'repeat', 'star', 'again ', 'bundle', 'stay', 'April', 'chance', 'squeak', 'cliff', 'baker', 'rule', 'pupil', 'misspell', 'lives', 'yell', 'sash'])

#Map all Project_Train Excerpts to its Score.
def initial(path):
    lines = []
    f = open(path+"project_train.txt",'r')
    for line in f:
        lines.append(unicode(line.replace("\n","").replace("\r",""), errors='ignore'))
    f.close()

    scores=[]
    f = open(path+"project_train_scores.txt",'r')
    for line in f:
        scores.append(float(line.replace("\n","").replace("\r","")))  
    f.close()
        
    return lines,scores

def get_entropy(excerpt):
    Dict = defaultdict(int) 
    
    words = word_tokenize(excerpt)
    for word in words:
        word = clean(word)
        if(word):
            Dict[word] +=1
    
    total = 0
    total_denom = float(sum(Dict.values()))
    for word in Dict:
        prob = Dict[word]/total_denom
        total+= prob*(math.log(prob,2))

    return(total*(-1.0))

def syllable(word):
    vowels = 'aeiouy'
    count = 0
    
    if word[0] in vowels:
        count +=1        
    if word[len(word)-1] =='e':
        count -= 1
    if word.endswith('le'):
        count+=1
        
    for i,item in enumerate(word):
        if(i == 0):
            continue
        if word[i] in vowels and word[i-1] not in vowels:
            count +=1
            
    if count == 0:
        count +=1
    return count

def clean(word):
    punctuate = string.maketrans(string.punctuation, ' '*len(string.punctuation))
    
    try:
        word = word.encode('utf-8')
    except:
        word = unicode(word, errors='ignore')
        word = word.encode('utf-8')
    word = word.translate(punctuate).replace(" ","").strip().lower()
    if(word):
        return word
    else:
        return None
    
def clean_wsp(word):
    punctuate = string.maketrans(string.punctuation, ' '*len(string.punctuation))
    
    try:
        word = word.encode('utf-8')
    except:
        word = unicode(word, errors='ignore')
        word = word.encode('utf-8')
    word = word.translate(punctuate).strip().lower()
    if(word):
        return word
    else:
        return None

#7th feature
def flesch_kincaid(excerpt):
    #lower - easier
    total_sent = len(sent_tokenize(excerpt))
    words = word_tokenize(excerpt)
    total_words = len(words)
    total_syllables = 0
    for each in words:
        each =clean(each)
        if(each):
            total_syllables+=syllable(each)
    return 0.39*(total_words/total_sent) + 11.8*(total_syllables/total_words) - 15.59
    #print 11.8*(total_syllables/total_words)

def Dale_score(excerpt):
    return len([word for word in word_tokenize(excerpt) if word not in dale_data])/float(len(dale_data))

def ALan(excerpts, scores):    
    f = open('data/train/final_scores.txt','w')
    
    #for each excerpt
    for i,each in enumerate(excerpts):
        Main_dict = defaultdict(dict)
        #get sentences from excerpt
        each = clean_wsp(each)
        try:
            s_sent = sent_tokenize(each)
        except:
            each = unicode(each, errors='ignore')
            #print each
            
        Final = []
        #for each sentence
        for sent in s_sent:
            Final.append(word_tokenize(sent))

        #flatten the list of words
        Final_flatten = [item for sublist in Final for item in sublist]
            
        frequency_model = Counter(Final_flatten)
        nouns = 0
        for (l,s) in nltk.pos_tag(frequency_model.keys()):
            #print s
            if(s == "NN" or s == "NNP"):
                nouns+=1
        
        frac_freq = sum(1 for key,value in frequency_model.items() if key in stop_data)
        frac_rare = sum(1 for key,value in frequency_model.items() if value==1 )
        
        vocab_size = len(frequency_model)
        frac_freq = frac_freq / float(vocab_size)
        frac_rare =frac_rare / float(vocab_size)                
        frac_pos = nouns/float(vocab_size)
        
        f.write('{0},{1},{2},{3},{4},{5},{6},{7}\n'.format(vocab_size, frac_freq, frac_rare, frac_pos, get_entropy(each),flesch_kincaid(each), Dale_score(each)))
        
    f.close()
path = "data/"
lines,scores = initial(path)
ALan(lines,scores)

f_y = open('data/train/y.txt','w')
for each in scores:
    f_y.write(str(each)+'\n')
f_y.close()

# %%
##########ONLY TRAIN

import math
import string

# 1-6 type_str, vocab_size,frac_freq,frac_rare,median_word, average_word,frac_nyt))
# 7 Flesch-kincaid
# 8 unk/total (Dale)
# 9 ppl

stop_data = set(['', 'secondly', 'all', 'consider', 'whoever', 'four', 'edu', 'go', 'causes', 'seemed', 'rd', 'certainly', 'vs', 'to', 'asking', 'th', 'under', 'sorry', "a's", 'sent', '@', 'far', 'every', 'yourselves', '`', "we'll", 'went', 'did', 'forth', "they've", 'try', 'p', "it'll", "i'll", 'says', "you'd", 'yourself', 'likely', 'further', 'quite', 'even', 'what', 'appear', 'brief', 'goes', 'sup', 'new', ';', 'ever', "c'mon", 'whose', 'respectively', 'never', 'here', 'let', 'others', "hadn't", 'along', "aren't", 'k', 'allows', "i'd", 'howbeit', 'usually', 'whereupon', "i'm", 'changes', 'thats', 'hither', 'via', 'followed', 'merely', 'while', 'viz', 'everybody', 'use', 'from', 'would', 'contains', 'two', 'next', 'few', 'therefore', 'taken', 'themselves', 'thru', 'tell', 'more', '``', 'knows', 'becomes', 'hereby', 'herein', "ain't", 'particular', 'known', 'must', 'me', 'none', 'f', 'this', 'oh', 'anywhere', 'nine', 'can', 'theirs', 'following', 'my', 'example', 'indicated', "didn't", 'indicates', 'something', 'want', 'needs', 'rather', 'meanwhile', 'how', 'instead', 'okay', 'tried', 'may', 'after', 'different', 'hereupon', 'such', 'a', 'third', 'whenever', 'maybe', 'appreciate', 'q', ')', 'ones', 'so', 'specifying', 'allow', 'keeps', "that's", 'six', 'help', "don't", 'indeed', 'over', 'mainly', 'soon', 'course', 'through', 'looks', 'still', 'its', 'before', 'thank', "he's", 'selves', 'inward', ',', 'actually', 'better', 'whether', 'willing', 'thanx', 'ours', 'might', '<', "haven't", 'then', 'non', 'someone', 'somebody', 'thereby', "you've", 'they', 'not', 'now', 'nor', 'several', 'hereafter', 'always', 'reasonably', 'whither', 'l', 'each', 'entirely', "isn't", 'mean', 'everyone', 'doing', 'eg', 'ex', 'our', 'beyond', 'out', 'them', 'furthermore', 'since', 'looking', 're', 'seriously', "shouldn't", "they'll", 'got', 'cause', 'thereupon', "you're", 'given', 'like', 'que', 'besides', 'x', 'ask', 'anyhow', 'g', 'could', 'tries', 'keep', 'w', 'ltd', 'hence', 'onto', 'think', 'first', 'already', 'seeming', 'thereafter', 'one', 'done', 'another', 'awfully', "doesn't", 'little', 'their', 'accordingly', 'least', 'name', 'anyone', 'indicate', 'too', 'gives', 'mostly', 'behind', 'nobody', 'took', 'immediate', 'regards', 'somewhat', 'off', 'believe', 'herself', 'than', "here's", 'b', 'unfortunately', 'gotten', 'second', 'i', 'r', 'were', 'toward', 'are', 'and', 'beforehand', 'say', 'unlikely', 'have', 'need', 'seen', 'seem', 'saw', 'any', 'relatively', 'zero', 'thoroughly', 'latter', 'that', 'downwards', 'aside', 'thorough', 'also', 'take', 'which', 'exactly', 'unless', 'shall', 'who', "where's", 'most', 'eight', 'but', 'nothing', 'why', 'sub', 'especially', 'noone', 'later', 'm', 'yours', "you'll", 'definitely', 'normally', 'came', 'saying', 'particularly', 'anyway', 'fifth', '(', 'outside', 'should', 'only', 'going', 'specify', 'do', 'his', 'above', 'get', 'between', 'overall', 'truly', "they'd", 'cannot', 'nearly', 'despite', 'during', 'him', 'regarding', 'qv', 'h', 'twice', 'she', 'contain', "won't", 'where', 'thanks', 'ignored', 'up', 'namely', 'anyways', 'best', 'wonder', 'said', 'away', 'currently', 'please', 'enough', "there's", 'various', 'hopefully', 'probably', 'neither', 'across', 'available', 'we', 'useful', 'however', 'come', 'both', 'c', 'last', 'many', "wouldn't", 'thence', 'according', 'against', 'etc', 's', 'became', 'com', "can't", 'otherwise', 'among', 'liked', 'co', 'afterwards', 'seems', 'whatever', 'alone', "couldn't", 'moreover', 'throughout', 'considering', 'sensible', 'described', "it's", 'three', 'been', '.', 'whom', 'much', 'wherein', 'hardly', "it'd", '>', 'wants', 'corresponding', 'latterly', 'concerning', 'else', 'hers', 'former', 'those', 'myself', 'novel', 'look', 'these', 'value', 'n', 'will', 'near', 'theres', 'seven', 'whereafter', 'almost', 'wherever', 'is', 'thus', 'it', 'cant', 'itself', 'in', 'ie', 'y', 'if', 'containing', 'perhaps', 'insofar', 'same', 'clearly', 'beside', 'when', 'gets', "weren't", 'used', 'see', 'somewhere', 'upon', 'uses', 'kept', 'whereby', 'nevertheless', 'whole', 'well', 'anybody', 'obviously', 'without', 'comes', 'very', 'the', 'self', 'lest', 'just', 'less', 'being', 'able', 'presumably', 'greetings', 'regardless', 'yes', 'yet', 'unto', '$', "we've", 'had', 'except', 'has', 'ought', "t's", 'around', "who's", 'possible', 'five', 'know', 'using', 'apart', 'necessary', 'd', 'follows', 'either', 'become', 'towards', 'therein', 'because', 'old', 'often', 'some', 'somehow', 'sure', 'specified', 'ourselves', 'happens', 'for', 'though', 'per', 'everything', 'does', 'provides', 'tends', 't', 'be', 'nowhere', 'although', 'by', 'on', 'about', 'ok', 'anything', 'getting', 'of', 'v', 'o', 'whence', 'plus', 'consequently', 'or', 'seeing', 'own', 'formerly', 'into', 'within', 'down', 'appropriate', 'right', "c's", 'your', 'her', 'there', 'inasmuch', 'inner', 'way', ':', 'was', 'himself', 'elsewhere', "i've", 'becoming', 'amongst', 'hi', 'trying', 'with', 'he', "they're", "wasn't", 'wish', 'j', "hasn't", 'us', 'until', 'placed', 'below', 'un', 'z', "we'd", 'gone', 'sometimes', 'associated', 'certain', 'am', 'an', 'as', 'sometime', 'at', 'et', 'inc', 'again', 'uucp', '%', 'no', 'whereas', 'nd', 'lately', 'other', 'you', 'really', "what's", "'s", 'welcome', "let's", 'serious', 'e', 'together', 'having', 'u', "we're", 'everywhere', 'hello', 'once'])
dale_data = set(['pardon', 'yellow', 'hitch', 'four', 'woods', 'sleep', 'captain', 'hate', 'yonder', 'lace', 'trolley', 'whose', 'electricity', 'swan', 'tickle', 'swat', 'teaspoon', 'under', 'lord', 'sorry', 'chill', 'worth', 'tame', 'blanket', 'rise', 'vase', 'shoot', 'smack', 'every', 'govern', 'fireplace', 'school', 'baking', 'prize', 'buttonhole', 'clothes', 'enjoy', 'chew', 'bicycle', 'quilt', 'clover', 'bacon', 'direct', 'horn', 'nail', 'likely', 'street', 'summer', 'writing', 'shining', 'blue', 'hide', 'pace', 'thunder', 'cooking', 'near', 'liberty', 'sung', 'aged ', 'new', 'net', 'ever', 'told', 'hero', 'men', 'drew', 'herd', 'met', 'mew', 'bookcase', 'china', 'hers', 'path', "aren't", 'dry', 'daughter', 'study',
y', 'bumblebee', 'cent', 'reindeer', 'drank', 'slowly', 'roller', 'eraser', 'certain', 'ship', 'curtain', 'feather', 'kitchen', 'killed', 'youngster', 'penny', 'nickel', 'am', 'Thursday', 'bull', 'bulb', 'general', 'gunpowder', 'painter', 'holiday', 'plain', 'value', 'chalk', 'fault', 'nevermore', 'handwriting', 'bathtub', 'helper', 'surface', 'rooster', 'hardware', 'lonely', 'partner', 'wreck', 'whirl', 'steer', 'perhaps', 'began', 'cross', 'member', 'wicked', 'when', 'strange', 'speaker', 'flour', 'inch', 'party', 'fill', 'ball', 'slave', 'drink', 'upon', 'beast', 'absent ', 'grandstand', 'painful', 'dust', 'overalls', 'collar', 'single', 'off', 'center', 'fully', 'weapon', 'well', 'thought', 'drawing', 'cried', 'flesh', 'boot', 'wren', 'loaf', 'front', 'Sunday', 'glue', 'lettuce', 'happiness', 'flashlight', 'web', 'wee', 'tight', 'Friday', 'sky', 'gum', 'bench', 'other', 'crack', 'ought', 'ski', 'kick', 'oar', 'knob', 'sick', 'government', "who's", 'haul', 'five', 'know', 'knot', 'desk', 'tick', "who'd", 'name', 'loss', 'helpful', 'lost', 'sofa', 'candy', 'garage', 'sissy', 'lose', 'become', 'soft', 'page', 'heel', 'shed', 'because', 'tumble', 'village', 'junk', 'hail', 'hair', 'alike ', 'proper', 'home', 'liking', "shan't", 'leaf', 'lead', 'broad', 'kettle', 'lean', 'shone', 'leap', 'campfire', 'fisherman', 'leader', 'season', 'pepper', 'hose', 'obey', 'pear', 'mitt', 'peas', 'host', 'stormy', 'paste', 'swept', 'noisy', 'throne', 'about', 'getting', 'column', 'freedom', 'biscuit', 'flake', 'swear', 'toadstool', 'blackness', 'cranberry', 'tongue', 'upward', 'swimming', 'owl', 'own', 'owe', 'payment', 'tag', 'socks', 'cocoa', 'guard', 'weather', 'promise', 'brush', 'custard', 'rowboat', 'rejoice', 'scrap', 'whom', 'buckle', 'soil', 'watchman', 'visitor', 'November', 'ivory', 'buy', 'north', 'catsup', 'bus', 'but', 'bun', 'ho', 'bum', 'good-bye', 'ha', 'eat', 'bud', 'he', 'count', 'misty', 'made', 'wise', 'glory', 'dangerous', 'smooth', 'flip', 'nightgown', 'pansy', 'record', 'carriage', 'stories', 'woke', 'cake', 'piece', 'pin', 'mask', 'circus', 'pie', 'pig', 'inn', 'goodness', 'ink', 'partly', 'pit', 'happen', 'squirrel', 'pussycat', 'accident ', 'coffeepot', 'book', 'boom', 'branch', 'out', "you're", 'dresser', 'February', 'repeat', 'star', 'again ', 'bundle', 'stay', 'April', 'chance', 'squeak', 'cliff', 'baker', 'rule', 'pupil', 'misspell', 'lives', 'yell', 'sash'])

#Map all Project_Train Excerpts to its Score.
def initial(path):
    lines = []
    f = open(path+"project_train.txt",'r')
    for line in f:
        lines.append(unicode(line.replace("\n","").replace("\r",""), errors='ignore'))
    f.close()

    scores=[]
    f = open(path+"project_train_scores.txt",'r')
    for line in f:
        scores.append(float(line.replace("\n","").replace("\r","")))  
    f.close()
        
    return lines,scores

def get_entropy(excerpt):
    Dict = defaultdict(int) 
    
    words = word_tokenize(excerpt)
    for word in words:
        word = clean(word)
        if(word):
            Dict[word] +=1
    
    total = 0
    total_denom = float(sum(Dict.values()))
    for word in Dict:
        prob = Dict[word]/total_denom
        total+= prob*(math.log(prob,2))

    return(total*(-1.0))

def syllable(word):
    vowels = 'aeiouy'
    count = 0
    
    if word[0] in vowels:
        count +=1        
    if word[len(word)-1] =='e':
        count -= 1
    if word.endswith('le'):
        count+=1
        
    for i,item in enumerate(word):
        if(i == 0):
            continue
        if word[i] in vowels and word[i-1] not in vowels:
            count +=1
            
    if count == 0:
        count +=1
    return count

def clean(word):
    punctuate = string.maketrans(string.punctuation, ' '*len(string.punctuation))
    
    try:
        word = word.encode('utf-8')
    except:
        word = unicode(word, errors='ignore')
        word = word.encode('utf-8')
    word = word.translate(punctuate).replace(" ","").strip().lower()
    if(word):
        return word
    else:
        return None
    
def clean_wsp(word):
    punctuate = string.maketrans(string.punctuation, ' '*len(string.punctuation))
    
    try:
        word = word.encode('utf-8')
    except:
        word = unicode(word, errors='ignore')
        word = word.encode('utf-8')
    word = word.translate(punctuate).strip().lower()
    if(word):
        return word
    else:
        return None

#7th feature
def flesch_kincaid(excerpt):
    #lower - easier
    total_sent = len(sent_tokenize(excerpt))
    words = word_tokenize(excerpt)
    total_words = len(words)
    total_syllables = 0
    for each in words:
        each =clean(each)
        if(each):
            total_syllables+=syllable(each)
    return 0.39*(total_words/total_sent) + 11.8*(total_syllables/total_words) - 15.59
    #print 11.8*(total_syllables/total_words)

def Dale_score(excerpt):
    return len([word for word in word_tokenize(excerpt) if word not in dale_data])/float(len(dale_data))

def ALan(excerpts, scores):    
    f = open('data/test/final_scores.txt','w')
    
    #for each excerpt
    for i,each in enumerate(excerpts):
        Main_dict = defaultdict(dict)
        #get sentences from excerpt
        each = clean_wsp(each)
        try:
            s_sent = sent_tokenize(each)
        except:
            each = unicode(each, errors='ignore')
            #print each
            
        Final = []
        #for each sentence
        for sent in s_sent:
            Final.append(word_tokenize(sent))
            
        #flatten the list of words
        Final_flatten = [item for sublist in Final for item in sublist]
        frequency_model = Counter(Final_flatten)
        
        nouns =0 
        for (l,s) in nltk.pos_tag(frequency_model.keys()):
            #print s
            if(s == "NN" or s == "NNP"):
                nouns+=1
        
        frac_freq = sum(1 for key,value in frequency_model.items() if key in stop_data)
        frac_rare = sum(1 for key,value in frequency_model.items() if value==1 )
        
        vocab_size = len(frequency_model)
        frac_freq = frac_freq / float(vocab_size)
        frac_rare =frac_rare / float(vocab_size)                
        frac_pos = nouns/float(vocab_size)
        
        f.write('{0},{1},{2},{3},{4},{5},{6}\n'.format(vocab_size, frac_freq, frac_rare, frac_pos, get_entropy(each),flesch_kincaid(each), Dale_score(each)))
        
    f.close()
    

lines,scores = initial(path)
#ALan(lines,scores)
f1 = open('data/project_test.txt','r')
lines = []
for each in f1:
    lines.append(each.replace("\n","").replace("\r",""))
f1.close()
ALan(lines,[])

# %%
###1

import numpy as np
from sklearn.tree import DecisionTreeRegressor

file1 = open('data/train/final_scores.txt','r')
allData = np.loadtxt(file1, delimiter=',')

X = np.matrix(allData)

file2 = open('data/train/y.txt','r')
allData2 = np.loadtxt(file2)
y = np.matrix((allData2)).T

regr_1 = DecisionTreeRegressor(max_depth=3)
regr_1.fit(X, y)
# Out:
# DecisionTreeRegressor(criterion='mse', max_depth=3, max_features=None,
#            max_leaf_nodes=None, min_impurity_split=1e-07,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#            splitter='best')

# %%
file3 = open('data/test/final_scores.txt','r')
allData3 = np.loadtxt(file3, delimiter=',')

Xtest = np.matrix(allData3)

res = regr_1.predict(Xtest)

f_res = open('data/test/test.txt','w')
for val in res:
    #print type(val)
    f_res.write(str(val)+"\n")
f_res.close()

# %%
import math
import string

# 1-6 type_str, vocab_size,frac_freq,frac_rare,median_word, average_word,frac_nyt))
# 7 Flesch-kincaid
# 8 unk/total (Dale)
# 9 ppl

stop_data = set(['', 'secondly', 'all', 'consider', 'whoever', 'four', 'edu', 'go', 'causes', 'seemed', 'rd', 'certainly', 'vs', 'to', 'asking', 'th', 'under', 'sorry', "a's", 'sent', '@', 'far', 'every', 'yourselves', '`', "we'll", 'went', 'did', 'forth', "they've", 'try', 'p', "it'll", "i'll", 'says', "you'd", 'yourself', 'likely', 'further', 'quite', 'even', 'what', 'appear', 'brief', 'goes', 'sup', 'new', ';', 'ever', "c'mon", 'whose', 'respectively', 'never', 'here', 'let', 'others', "hadn't", 'along', "aren't", 'k', 'allows', "i'd", 'howbeit', 'usually', 'whereupon', "i'm", 'changes', 'thats', 'hither', 'via', 'followed', 'merely', 'while', 'viz', 'everybody', 'use', 'from', 'would', 'contains', 'two', 'next', 'few', 'therefore', 'taken', 'themselves', 'thru', 'tell', 'more', '``', 'knows', 'becomes', 'hereby', 'herein', "ain't", 'particular', 'known', 'must', 'me', 'none', 'f', 'this', 'oh', 'anywhere', 'nine', 'can', 'theirs', 'following', 'my', 'example', 'indicated', "didn't", 'indicates', 'something', 'want', 'needs', 'rather', 'meanwhile', 'how', 'instead', 'okay', 'tried', 'may', 'after', 'different', 'hereupon', 'such', 'a', 'third', 'whenever', 'maybe', 'appreciate', 'q', ')', 'ones', 'so', 'specifying', 'allow', 'keeps', "that's", 'six', 'help', "don't", 'indeed', 'over', 'mainly', 'soon', 'course', 'through', 'looks', 'still', 'its', 'before', 'thank', "he's", 'selves', 'inward', ',', 'actually', 'better', 'whether', 'willing', 'thanx', 'ours', 'might', '<', "haven't", 'then', 'non', 'someone', 'somebody', 'thereby', "you've", 'they', 'not', 'now', 'nor', 'several', 'hereafter', 'always', 'reasonably', 'whither', 'l', 'each', 'entirely', "isn't", 'mean', 'everyone', 'doing', 'eg', 'ex', 'our', 'beyond', 'out', 'them', 'furthermore', 'since', 'looking', 're', 'seriously', "shouldn't", "they'll", 'got', 'cause', 'thereupon', "you're", 'given', 'like', 'que', 'besides', 'x', 'ask', 'anyhow', 'g', 'could', 'tries', 'keep', 'w', 'ltd', 'hence', 'onto', 'think', 'first', 'already', 'seeming', 'thereafter', 'one', 'done', 'another', 'awfully', "doesn't", 'little', 'their', 'accordingly', 'least', 'name', 'anyone', 'indicate', 'too', 'gives', 'mostly', 'behind', 'nobody', 'took', 'immediate', 'regards', 'somewhat', 'off', 'believe', 'herself', 'than', "here's", 'b', 'unfortunately', 'gotten', 'second', 'i', 'r', 'were', 'toward', 'are', 'and', 'beforehand', 'say', 'unlikely', 'have', 'need', 'seen', 'seem', 'saw', 'any', 'relatively', 'zero', 'thoroughly', 'latter', 'that', 'downwards', 'aside', 'thorough', 'also', 'take', 'which', 'exactly', 'unless', 'shall', 'who', "where's", 'most', 'eight', 'but', 'nothing', 'why', 'sub', 'especially', 'noone', 'later', 'm', 'yours', "you'll", 'definitely', 'normally', 'came', 'saying', 'particularly', 'anyway', 'fifth', '(', 'outside', 'should', 'only', 'going', 'specify', 'do', 'his', 'above', 'get', 'between', 'overall', 'truly', "they'd", 'cannot', 'nearly', 'despite', 'during', 'him', 'regarding', 'qv', 'h', 'twice', 'she', 'contain', "won't", 'where', 'thanks', 'ignored', 'up', 'namely', 'anyways', 'best', 'wonder', 'said', 'away', 'currently', 'please', 'enough', "there's", 'various', 'hopefully', 'probably', 'neither', 'across', 'available', 'we', 'useful', 'however', 'come', 'both', 'c', 'last', 'many', "wouldn't", 'thence', 'according', 'against', 'etc', 's', 'became', 'com', "can't", 'otherwise', 'among', 'liked', 'co', 'afterwards', 'seems', 'whatever', 'alone', "couldn't", 'moreover', 'throughout', 'considering', 'sensible', 'described', "it's", 'three', 'been', '.', 'whom', 'much', 'wherein', 'hardly', "it'd", '>', 'wants', 'corresponding', 'latterly', 'concerning', 'else', 'hers', 'former', 'those', 'myself', 'novel', 'look', 'these', 'value', 'n', 'will', 'near', 'theres', 'seven', 'whereafter', 'almost', 'wherever', 'is', 'thus', 'it', 'cant', 'itself', 'in', 'ie', 'y', 'if', 'containing', 'perhaps', 'insofar', 'same', 'clearly', 'beside', 'when', 'gets', "weren't", 'used', 'see', 'somewhere', 'upon', 'uses', 'kept', 'whereby', 'nevertheless', 'whole', 'well', 'anybody', 'obviously', 'without', 'comes', 'very', 'the', 'self', 'lest', 'just', 'less', 'being', 'able', 'presumably', 'greetings', 'regardless', 'yes', 'yet', 'unto', '$', "we've", 'had', 'except', 'has', 'ought', "t's", 'around', "who's", 'possible', 'five', 'know', 'using', 'apart', 'necessary', 'd', 'follows', 'either', 'become', 'towards', 'therein', 'because', 'old', 'often', 'some', 'somehow', 'sure', 'specified', 'ourselves', 'happens', 'for', 'though', 'per', 'everything', 'does', 'provides', 'tends', 't', 'be', 'nowhere', 'although', 'by', 'on', 'about', 'ok', 'anything', 'getting', 'of', 'v', 'o', 'whence', 'plus', 'consequently', 'or', 'seeing', 'own', 'formerly', 'into', 'within', 'down', 'appropriate', 'right', "c's", 'your', 'her', 'there', 'inasmuch', 'inner', 'way', ':', 'was', 'himself', 'elsewhere', "i've", 'becoming', 'amongst', 'hi', 'trying', 'with', 'he', "they're", "wasn't", 'wish', 'j', "hasn't", 'us', 'until', 'placed', 'below', 'un', 'z', "we'd", 'gone', 'sometimes', 'associated', 'certain', 'am', 'an', 'as', 'sometime', 'at', 'et', 'inc', 'again', 'uucp', '%', 'no', 'whereas', 'nd', 'lately', 'other', 'you', 'really', "what's", "'s", 'welcome', "let's", 'serious', 'e', 'together', 'having', 'u', "we're", 'everywhere', 'hello', 'once'])
', 'rowboat', 'rejoice', 'scrap', 'whom', 'buckle', 'soil', 'watchman', 'visitor', 'November', 'ivory', 'buy', 'north', 'catsup', 'bus', 'but', 'bun', 'ho', 'bum', 'good-bye', 'ha', 'eat', 'bud', 'he', 'count', 'misty', 'made', 'wise', 'glory', 'dangerous', 'smooth', 'flip', 'nightgown', 'pansy', 'record', 'carriage', 'stories', 'woke', 'cake', 'piece', 'pin', 'mask', 'circus', 'pie', 'pig', 'inn', 'goodness', 'ink', 'partly', 'pit', 'happen', 'squirrel', 'pussycat', 'accident ', 'coffeepot', 'book', 'boom', 'branch', 'out', "you're", 'dresser', 'February', 'repeat', 'star', 'again ', 'bundle', 'stay', 'April', 'chance', 'squeak', 'cliff', 'baker', 'rule', 'pupil', 'misspell', 'lives', 'yell', 'sash'])

#Map all Project_Train Excerpts to its Score.
def initial(path):
    opt_scores = path+"optional_training/"
    lines = []
    f = open(path+"project_train.txt",'r')
    for line in f:
        lines.append(unicode(line.replace("\n","").replace("\r",""), errors='ignore'))

    f.close()

    scores=[]
    f = open(path+"project_train_scores.txt",'r')
    for line in f:
        scores.append(float(line.replace("\n","").replace("\r","")))  

    f.close()

    name_score_mapping = {}
    f = open(opt_scores+"optional_project_train_scores.txt",'r')
    for line in f:
        l = line.split()
        name_score_mapping[l[0]+".txt"] = l[1]

    f.close()


    unit = (float(max(name_score_mapping.values())) - float(min(name_score_mapping.values())))/10.0
    max_val = float(max(name_score_mapping.values()))
    #print(unit)
    normalized_name_score_mapping = {}

    for key,val in name_score_mapping.items():
        normalized_name_score_mapping[key] = math.floor((max_val - float(val))/unit)

    #print(normalized_name_score_mapping)

    for key,val in normalized_name_score_mapping.items():
        f = open(opt_scores+key,'r')
        string = f.read().replace("\n","").replace("\r","")
        lines.append(string.replace("\n","").replace("\r",""))
        scores.append(val)
        
    return lines,scores

def get_type_token_ratio(excerpt):
    Dict = defaultdict(int)
    
    words = word_tokenize(excerpt)
    for word in words:
        word =clean(word)
        if(word):
            Dict[word] +=1
    
    type_str = len(Dict)
    token_str = sum(Dict.values())
    
    return type_str/float(token_str)

def get_entropy(excerpt):
    Dict = defaultdict(int) 
    
    words = word_tokenize(excerpt)
    for word in words:
        word = clean(word)
        if(word):
            Dict[word] +=1
    
    total = 0
    total_denom = float(sum(Dict.values()))
    for word in Dict:
        prob = Dict[word]/total_denom
        total+= prob*(math.log(prob,2))

    return(total*(-1.0))

def syllable(word):
    vowels = 'aeiouy'
    count = 0
    
    if word[0] in vowels:
        count +=1        
    if word[len(word)-1] =='e':
        count -= 1
    if word.endswith('le'):
        count+=1
        
    for i,item in enumerate(word):
        if(i == 0):
            continue
        if word[i] in vowels and word[i-1] not in vowels:
            count +=1
            
    if count == 0:
        count +=1
    return count

def clean(word):
    punctuate = string.maketrans(string.punctuation, ' '*len(string.punctuation))
    
    try:
        word = word.encode('utf-8')
    except:
        word = unicode(word, errors='ignore')
        word = word.encode('utf-8')
    word = word.translate(punctuate).replace(" ","").strip().lower()
    if(word):
        return word
    else:
        return None
    
def clean_wsp(word):
    punctuate = string.maketrans(string.punctuation, ' '*len(string.punctuation))
    
    try:
        word = word.encode('utf-8')
    except:
        word = unicode(word, errors='ignore')
        word = word.encode('utf-8')
    word = word.translate(punctuate).strip().lower()
    if(word):
        return word
    else:
        return None

#7th feature
def flesch_kincaid(excerpt):
    #lower - easier
    total_sent = len(sent_tokenize(excerpt))
    words = word_tokenize(excerpt)
    total_words = len(words)
    total_syllables = 0
    for each in words:
        each =clean(each)
        if(each):
            total_syllables+=syllable(each)
    return 0.39*(total_words/total_sent) + 11.8*(total_syllables/total_words) - 15.59
    #print 11.8*(total_syllables/total_words)

def find_median(list_of_strings):
    list_of_strings.sort(lambda x,y: cmp(len(x), len(y)))
    list_length= len(list_of_strings)
    if(list_length%2 != 0):
        return(len(list_of_strings[int(list_length/2)]))
    else:
        return(len(list_of_strings[int((list_length+1)/2)]))
       
def find_average(list_of_strings):
    c=Counter([len(word) for word in sorted(list_of_strings, key=len)])       
    return(sum([x*y for x,y in c.items()])/float(sum(c.values())))

def Dale_score(excerpt):
    return len([word for word in word_tokenize(excerpt) if word not in dale_data])/float(len(dale_data))

def ALan(excerpts, scores):    
    f = open('data/train/final_scores.txt','w')
    f1 = open('data/train/ppl_scores.txt','r')
    ppl = []
    for each in f1:
        ppl.append(each.replace("\n",""))
    f1.close()
    
    #for each excerpt
    for i,each in enumerate(excerpts):
        if(i==0):
            print each
        
        Main_dict = defaultdict(dict)
        #get sentences from excerpt
        each = clean_wsp(each)
        try:
            s_sent = sent_tokenize(each)
        except:
            each = unicode(each, errors='ignore')
            #print each
            
        Final = []
        #for each sentence
        for sent in s_sent:
            temp = [word for word in word_tokenize(sent) if word not in stop_data]
            Final.append(temp)
            
        #flatten the list of words
        Final_flatten = [item for sublist in Final for item in sublist]    
        median_word = find_median(Final_flatten)
        average_word = find_average(Final_flatten)
        frequency_model = Counter(Final_flatten)
        
        vocab_size = len(frequency_model)
        
        frac_freq = sum(1 for key,value in frequency_model.items() if key in stop_data)
        frac_rare = sum(1 for key,value in frequency_model.items() if value==1 )
        frac_freq = frac_freq / float(vocab_size)
        frac_rare =frac_rare / float(vocab_size)
        
        f.write('{0},{1},{2},{3},{4},{5}\n'.format(vocab_size,frac_rare,average_word, get_entropy(each),flesch_kincaid(each), Dale_score(each)))
        
    f.close()
    
lines,scores = initial(path)
ALan(lines,scores)

f_y = open('data/train/y.txt','w')
for each in scores:
    f_y.write(str(each)+'\n')
f_y.close()
# Out:
# The treatment of an intra-articular osteoid osteoma is sometimes challenging, because of its location. We report a patient with an intra-articular osteoid osteoma of the lateral tibial plateau which was excised under an arthroscopically assisted procedure. After total resection of the intra-articular osteoid osteoma, the osteochondral defect of the lateral tibial plateau was reconstructed with a retrograde autogenous osteochondral graft which was harvested from the non-weightbearing area of the distal femur.

# %%
import math
import string

# 1-6 type_str, vocab_size,frac_freq,frac_rare,median_word, average_word,frac_nyt))
# 7 Flesch-kincaid
# 8 unk/total (Dale)
# 9 ppl

stop_data = set(['', 'secondly', 'all', 'consider', 'whoever', 'four', 'edu', 'go', 'causes', 'seemed', 'rd', 'certainly', 'vs', 'to', 'asking', 'th', 'under', 'sorry', "a's", 'sent', '@', 'far', 'every', 'yourselves', '`', "we'll", 'went', 'did', 'forth', "they've", 'try', 'p', "it'll", "i'll", 'says', "you'd", 'yourself', 'likely', 'further', 'quite', 'even', 'what', 'appear', 'brief', 'goes', 'sup', 'new', ';', 'ever', "c'mon", 'whose', 'respectively', 'never', 'here', 'let', 'others', "hadn't", 'along', "aren't", 'k', 'allows', "i'd", 'howbeit', 'usually', 'whereupon', "i'm", 'changes', 'thats', 'hither', 'via', 'followed', 'merely', 'while', 'viz', 'everybody', 'use', 'from', 'would', 'contains', 'two', 'next', 'few', 'therefore', 'taken', 'themselves', 'thru', 'tell', 'more', '``', 'knows', 'becomes', 'hereby', 'herein', "ain't", 'particular', 'known', 'must', 'me', 'none', 'f', 'this', 'oh', 'anywhere', 'nine', 'can', 'theirs', 'following', 'my', 'example', 'indicated', "didn't", 'indicates', 'something', 'want', 'needs', 'rather', 'meanwhile', 'how', 'instead', 'okay', 'tried', 'may', 'after', 'different', 'hereupon', 'such', 'a', 'third', 'whenever', 'maybe', 'appreciate', 'q', ')', 'ones', 'so', 'specifying', 'allow', 'keeps', "that's", 'six', 'help', "don't", 'indeed', 'over', 'mainly', 'soon', 'course', 'through', 'looks', 'still', 'its', 'before', 'thank', "he's", 'selves', 'inward', ',', 'actually', 'better', 'whether', 'willing', 'thanx', 'ours', 'might', '<', "haven't", 'then', 'non', 'someone', 'somebody', 'thereby', "you've", 'they', 'not', 'now', 'nor', 'several', 'hereafter', 'always', 'reasonably', 'whither', 'l', 'each', 'entirely', "isn't", 'mean', 'everyone', 'doing', 'eg', 'ex', 'our', 'beyond', 'out', 'them', 'furthermore', 'since', 'looking', 're', 'seriously', "shouldn't", "they'll", 'got', 'cause', 'thereupon', "you're", 'given', 'like', 'que', 'besides', 'x', 'ask', 'anyhow', 'g', 'could', 'tries', 'keep', 'w', 'ltd', 'hence', 'onto', 'think', 'first', 'already', 'seeming', 'thereafter', 'one', 'done', 'another', 'awfully', "doesn't", 'little', 'their', 'accordingly', 'least', 'name', 'anyone', 'indicate', 'too', 'gives', 'mostly', 'behind', 'nobody', 'took', 'immediate', 'regards', 'somewhat', 'off', 'believe', 'herself', 'than', "here's", 'b', 'unfortunately', 'gotten', 'second', 'i', 'r', 'were', 'toward', 'are', 'and', 'beforehand', 'say', 'unlikely', 'have', 'need', 'seen', 'seem', 'saw', 'any', 'relatively', 'zero', 'thoroughly', 'latter', 'that', 'downwards', 'aside', 'thorough', 'also', 'take', 'which', 'exactly', 'unless', 'shall', 'who', "where's", 'most', 'eight', 'but', 'nothing', 'why', 'sub', 'especially', 'noone', 'later', 'm', 'yours', "you'll", 'definitely', 'normally', 'came', 'saying', 'particularly', 'anyway', 'fifth', '(', 'outside', 'should', 'only', 'going', 'specify', 'do', 'his', 'above', 'get', 'between', 'overall', 'truly', "they'd", 'cannot', 'nearly', 'despite', 'during', 'him', 'regarding', 'qv', 'h', 'twice', 'she', 'contain', "won't", 'where', 'thanks', 'ignored', 'up', 'namely', 'anyways', 'best', 'wonder', 'said', 'away', 'currently', 'please', 'enough', "there's", 'various', 'hopefully', 'probably', 'neither', 'across', 'available', 'we', 'useful', 'however', 'come', 'both', 'c', 'last', 'many', "wouldn't", 'thence', 'according', 'against', 'etc', 's', 'became', 'com', "can't", 'otherwise', 'among', 'liked', 'co', 'afterwards', 'seems', 'whatever', 'alone', "couldn't", 'moreover', 'throughout', 'considering', 'sensible', 'described', "it's", 'three', 'been', '.', 'whom', 'much', 'wherein', 'hardly', "it'd", '>', 'wants', 'corresponding', 'latterly', 'concerning', 'else', 'hers', 'former', 'those', 'myself', 'novel', 'look', 'these', 'value', 'n', 'will', 'near', 'theres', 'seven', 'whereafter', 'almost', 'wherever', 'is', 'thus', 'it', 'cant', 'itself', 'in', 'ie', 'y', 'if', 'containing', 'perhaps', 'insofar', 'same', 'clearly', 'beside', 'when', 'gets', "weren't", 'used', 'see', 'somewhere', 'upon', 'uses', 'kept', 'whereby', 'nevertheless', 'whole', 'well', 'anybody', 'obviously', 'without', 'comes', 'very', 'the', 'self', 'lest', 'just', 'less', 'being', 'able', 'presumably', 'greetings', 'regardless', 'yes', 'yet', 'unto', '$', "we've", 'had', 'except', 'has', 'ought', "t's", 'around', "who's", 'possible', 'five', 'know', 'using', 'apart', 'necessary', 'd', 'follows', 'either', 'become', 'towards', 'therein', 'because', 'old', 'often', 'some', 'somehow', 'sure', 'specified', 'ourselves', 'happens', 'for', 'though', 'per', 'everything', 'does', 'provides', 'tends', 't', 'be', 'nowhere', 'although', 'by', 'on', 'about', 'ok', 'anything', 'getting', 'of', 'v', 'o', 'whence', 'plus', 'consequently', 'or', 'seeing', 'own', 'formerly', 'into', 'within', 'down', 'appropriate', 'right', "c's", 'your', 'her', 'there', 'inasmuch', 'inner', 'way', ':', 'was', 'himself', 'elsewhere', "i've", 'becoming', 'amongst', 'hi', 'trying', 'with', 'he', "they're", "wasn't", 'wish', 'j', "hasn't", 'us', 'until', 'placed', 'below', 'un', 'z', "we'd", 'gone', 'sometimes', 'associated', 'certain', 'am', 'an', 'as', 'sometime', 'at', 'et', 'inc', 'again', 'uucp', '%', 'no', 'whereas', 'nd', 'lately', 'other', 'you', 'really', "what's", "'s", 'welcome', "let's", 'serious', 'e', 'together', 'having', 'u', "we're", 'everywhere', 'hello', 'once'])
dale_data = set(['pardon', 'yellow', 'hitch', 'four', 'woods', 'sleep', 'captain', 'hate', 'yonder', 'lace', 'trolley', 'whose', 'electricity', 'swan', 'tickle', 'swat', 'teaspoon', 'under', 'lord', 'sorry', 'chill', 'worth', 'tame', 'blanket', 'rise', 'vase', 'shoot', 'smack', 'every', 'govern', 'fireplace', 'school', 'baking', 'prize', 'buttonhole', 'clothes', 'enjoy', 'chew', 'bicycle', 'quilt', 'clover', 'bacon', 'direct', 'horn', 'nail', 'likely', '
    opt_scores = path+"optional_training/"
    lines = []
    f = open(path+"project_train.txt",'r')
    for line in f:
        lines.append(unicode(line.replace("\n","").replace("\r",""), errors='ignore'))

    f.close()

    scores=[]
    f = open(path+"project_train_scores.txt",'r')
    for line in f:
        scores.append(float(line.replace("\n","").replace("\r","")))  

    f.close()

    name_score_mapping = {}
    f = open(opt_scores+"optional_project_train_scores.txt",'r')
    for line in f:
        l = line.split()
        name_score_mapping[l[0]+".txt"] = l[1]

    f.close()


    unit = (float(max(name_score_mapping.values())) - float(min(name_score_mapping.values())))/10.0
    max_val = float(max(name_score_mapping.values()))
    #print(unit)
    normalized_name_score_mapping = {}

    for key,val in name_score_mapping.items():
        normalized_name_score_mapping[key] = math.floor((max_val - float(val))/unit)

    #print(normalized_name_score_mapping)

    for key,val in normalized_name_score_mapping.items():
        f = open(opt_scores+key,'r')
        string = f.read().replace("\n","").replace("\r","")
        lines.append(string.replace("\n","").replace("\r",""))
        scores.append(val)
        
    return lines,scores

def get_type_token_ratio(excerpt):
    Dict = defaultdict(int)
    
    words = word_tokenize(excerpt)
    for word in words:
        word =clean(word)
        if(word):
            Dict[word] +=1
    
    type_str = len(Dict)
    token_str = sum(Dict.values())
    
    return type_str/float(token_str)

def get_entropy(excerpt):
    Dict = defaultdict(int) 
    
    words = word_tokenize(excerpt)
    for word in words:
        word = clean(word)
        if(word):
            Dict[word] +=1
    
    total = 0
    total_denom = float(sum(Dict.values()))
    for word in Dict:
        prob = Dict[word]/total_denom
        total+= prob*(math.log(prob,2))

    return(total*(-1.0))

def syllable(word):
    vowels = 'aeiouy'
    count = 0
    
    if word[0] in vowels:
        count +=1        
    if word[len(word)-1] =='e':
        count -= 1
    if word.endswith('le'):
        count+=1
        
    for i,item in enumerate(word):
        if(i == 0):
            continue
        if word[i] in vowels and word[i-1] not in vowels:
            count +=1
            
    if count == 0:
        count +=1
    return count

def clean(word):
    punctuate = string.maketrans(string.punctuation, ' '*len(string.punctuation))
    try:
        word = word.encode('utf-8')
    except:
        word = unicode(word, errors='ignore')
        word = word.encode('utf-8')
    word = word.translate(punctuate).replace(" ","").strip().lower()
    if(word):
        return word
    else:
        return None
    
def clean_wsp(word):
    punctuate = string.maketrans(string.punctuation, ' '*len(string.punctuation))
    try:
        word = word.encode('utf-8')
    except:
        word = unicode(word, errors='ignore')
        word = word.encode('utf-8')
    word = word.translate(punctuate).strip().lower()
    if(word):
        return word
    else:
        return None

#7th feature
def flesch_kincaid(excerpt):
    #lower - easier
    total_sent = len(sent_tokenize(excerpt))
    words = word_tokenize(excerpt)
    total_words = len(words)
    total_syllables = 0
    for each in words:
        each =clean(each)
        if(each):
            total_syllables+=syllable(each)
    return 0.39*(total_words/total_sent) + 11.8*(total_syllables/total_words) - 15.59
    #print 11.8*(total_syllables/total_words)

def find_median(list_of_strings):
    list_of_strings.sort(lambda x,y: cmp(len(x), len(y)))
    list_length= len(list_of_strings)
    if(list_length%2 != 0):
        return(len(list_of_strings[int(list_length/2)]))
    else:
        return(len(list_of_strings[int((list_length+1)/2)]))
       
def find_average(list_of_strings):
    c=Counter([len(word) for word in sorted(list_of_strings, key=len)])       
    return(sum([x*y for x,y in c.items()])/float(sum(c.values())))

def Dale_score(excerpt):
    return len([word for word in word_tokenize(excerpt) if word not in dale_data])/float(len(dale_data))

def ALan(excerpts, scores):    
    f = open('data/test/final_scores.txt','w')
    f1 = open('data/test/ppl_scores.txt','r')
    ppl = []
    for each in f1:
        ppl.append(each.replace("\n",""))
    f1.close()
    
    
    #for each excerpt
    for i,each in enumerate(excerpts):
        Main_dict = defaultdict(dict)
        each = clean_wsp(each)
        #get sentences from excerpt
        try:
            s_sent = sent_tokenize(each)
        except:
            each = unicode(each, errors='ignore')
            #print each
            
        Final = []
        #for each sentence
        for sent in s_sent:
            temp = [word for word in word_tokenize(sent) if word not in stop_data]
            Final.append(temp)
            
        #flatten the list of words
        Final_flatten = [item for sublist in Final for item in sublist]    
        median_word = find_median(Final_flatten)
        average_word = find_average(Final_flatten)
        frequency_model = Counter(Final_flatten)
        
        vocab_size = len(frequency_model)
        #print frequency_model
        
        frac_freq = sum(1 for key,value in frequency_model.items() if key in stop_data)
        frac_rare = sum(1 for key,value in frequency_model.items() if value==1 )
        frac_freq = frac_freq / float(vocab_size)
        frac_rare =frac_rare / float(vocab_size)
        f.write('{0},{1},{2},{3},{4},{5}\n'.format(vocab_size,frac_rare,average_word, get_entropy(each),flesch_kincaid(each), Dale_score(each)))
        
    f.close()
    

f1 = open('data/project_test.txt','r')
lines = []
for each in f1:
    lines.append(each.replace("\n","").replace("\r",""))
f1.close()
ALan(lines,[])

# %%
####main

import numpy as np
from sklearn.ensemble import RandomForestRegressor

file1 = open('data/train/final_scores.txt','r')
allData = np.loadtxt(file1, delimiter=',')

X = np.matrix(allData)

file2 = open('data/train/y.txt','r')
allData2 = np.loadtxt(file2)
y = np.matrix((allData2)).T

print y
# Out:
# [[  1.]
#  [  2.]
#  [  5.]
#  [  3.]
#  [  4.]
#  [  5.]
#  [  5.]
#  [  9.]
#  [  2.]
#  [  7.]
#  [ 10.]
#  [  8.]
#  [  5.]
#  [  6.]
#  [  4.]
#  [  4.]
#  [  9.]
#  [  3.]
#  [  1.]
#  [  9.]
#  [  4.]
#  [ 10.]
#  [  3.]
#  [ 10.]
#  [  1.]
#  [  4.]
#  [  5.]
#  [  7.]
#  [  6.]
#  [  5.]
#  [  9.]
#  [ 10.]
#  [  9.]
#  [  4.]
#  [  3.]
#  [  4.]
#  [  8.]
#  [  5.]
#  [ 10.]
#  [  6.]
#  [  2.]
#  [  2.]
#  [ 10.]
#  [  8.]
#  [  7.]
#  [  8.]
#  [  8.]
#  [  9.]
#  [  7.]
#  [  6.]
#  [  8.]
#  [  9.]
#  [  3.]
#  [  9.]
#  [  9.]
#  [  8.]
#  [  5.]
#  [  3.]
#  [  1.]
#  [  3.]
#  [  9.]
#  [  9.]
#  [  9.]
#  [  7.]
#  [  4.]
#  [  1.]
#  [  4.]
#  [  6.]
#  [  2.]
#  [  9.]
#  [  6.]
#  [  5.]
#  [  4.]
#  [  9.]
#  [  7.]
#  [  4.]
#  [  7.]
#  [  9.]
#  [  8.]
#  [  7.]
#  [  2.]
#  [  6.]
#  [  9.]
#  [  9.]
#  [  9.]
#  [  6.]
#  [  7.]
#  [  6.]
#  [  7.]
#  [  3.]
#  [  8.]
#  [  8.]
#  [  8.]
#  [  7.]
#  [  8.]
#  [  7.]
#  [  8.]
#  [  9.]
#  [  7.]
#  [  5.]
# ...

# %%
from sklearn.ensemble import RandomForestRegressor
n,d = X.shape
rf = RandomForestRegressor()

rf.fit(X,y)

file3 = open('data/test/final_scores.txt','r')
allData3 = np.loadtxt(file3, delimiter=',')

Xtest = np.matrix(allData3)

res = rf.predict(Xtest)

f_res = open('data/test/test.txt','w')
for val in res:
    #print type(val)
    f_res.write(str(val)+"\n")
f_res.close()
# Out:
# /home/swathi/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:5: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().

# %%
from sklearn import svm
file1 = open('data/train/final_scores.txt','r')
allData = np.loadtxt(file1, delimiter=',')

X = np.matrix(allData)

file2 = open('data/train/y.txt','r')
allData2 = np.loadtxt(file2)
y = np.matrix((allData2)).T


file3 = open('data/test/final_scores.txt','r')
allData3 = np.loadtxt(file3, delimiter=',')

Xtest = np.matrix(allData3)

clf = svm.SVR(C=1.0, kernel = 'linear', epsilon = 0.1)
clf.fit(X, y)
res = clf.predict(Xtest)


f_res = open('data/test/test.txt','w')
for val in res:
    #print type(val)
    f_res.write(str(val)+"\n")
f_res.close()

# %%
from sklearn.svm import SVC
from sklearn import svm
from sklearn.model_selection import cross_val_score

clf = svm.SVC(kernel='linear', C=1)
clf.fit(X, y)
cross_val_score(clf,X,y,cv=10)
# Out:
# /home/swathi/anaconda2/lib/python2.7/site-packages/sklearn/utils/validation.py:526: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/swathi/anaconda2/lib/python2.7/site-packages/sklearn/model_selection/_split.py:581: Warning: The least populated class in y has only 1 members, which is too few. The minimum number of groups for any class cannot be less than n_splits=10.
#   % (min_groups, self.n_splits)), Warning)
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-216-bf83c78c0d2c> in <module>()
#       5 clf = svm.SVC(kernel='linear', C=1)
#       6 clf.fit(X, y)
# ----> 7 cross_val_score(clf,X,y,cv=10)
#
# ...

# %%
import math

#Map all Project_Train Excerpts to its Score.
def initial(path):
    opt_scores = path+"optional_training/"
    lines = []
    f = open(path+"project_train.txt",'r')
    for line in f:
        lines.append(line.replace("\n","").replace("\r",""))

    f.close()

    scores=[]
    f = open(path+"project_train_scores.txt",'r')
    for line in f:
        scores.append(float(line.replace("\n","").replace("\r","")))  

    f.close()



    name_score_mapping = {}
    f = open(opt_scores+"optional_project_train_scores.txt",'r')
    for line in f:
        l = line.split()
        name_score_mapping[l[0]+".txt"] = l[1]

    f.close()


    unit = (float(max(name_score_mapping.values())) - float(min(name_score_mapping.values())))/10.0
    max_val = float(max(name_score_mapping.values()))
    #print(unit)
    normalized_name_score_mapping = {}

    for key,val in name_score_mapping.items():
        normalized_name_score_mapping[key] = math.floor((max_val - float(val))/unit)

    #print(normalized_name_score_mapping)

    for key,val in normalized_name_score_mapping.items():
        f = open(opt_scores+key,'r')
        string = f.read().replace("\n","").replace("\r","")
        lines.append(string.replace("\n","").replace("\r",""))
        scores.append(val)
        
    return lines,scores

path = "data/"
lines,scores = initial(path)
f = open("train_data.txt",'w')
for line in lines:
    f.write(line+"\n")
f.close()

# %%
def clean(word):
    punctuate = string.maketrans(string.punctuation, ' '*len(string.punctuation))
    word = word.translate(punctuate).replace(" ","").strip().lower()
    return word

def flesch_kincaid(excerpt):
    #lower - easier
    total_sent = len(sent_tokenize(excerpt))
    words = word_tokenize(excerpt)
    total_words = len(words)
    total_syllables = 0
    for each in words:
        each =clean(each)
        if(each):
            total_syllables+=syllable(each)
    print 0.39*(total_words/total_sent) + 11.8*(total_syllables/total_words) - 15.59
    #print 11.8*(total_syllables/total_words)
    
def create_feature(excerpts, y_values):
    #frac_dale, FK, 
    for excerpt in excerpts:
# Out:
#   File "<ipython-input-115-6ed040dca49d>", line 22
#
#     ^
# IndentationError: expected an indented block

# %%
excerpt = "The Australian platypus is seemingly a hybrid of a mammal and reptilian creature"
#excerpt = "I hate you"
#excerpt = "The progression from Barrett's metaplasia to adenocarcinoma is associated with the acquirement of an apoptosis-resistant phenotype. The bile acid deoxycholate (DCA) has been proposed to play an important role in the development of esophageal adenocarcinoma, but the precise molecular mechanisms remain undefined. The aim of this study was to investigate DCA-stimulated COX-2 signaling pathways and their possible contribution to deregulated cell survival and apoptosis in esophageal adenocarcinoma cells."
flesch_kincaid(excerpt)
# Out:
# 1.28

# %%
import os
import re
from nltk import sent_tokenize,word_tokenize

def atoi(text):
    return int(text) if text.isdigit() else text

def natural_keys(text):
    return [ atoi(c) for c in re.split('(\d+)', text) ]

def get_all_files(directory):
    if(os.path.isdir(directory)):
        files = os.listdir(directory)
        file_list=[]
        for f in files:
            if (os.path.isfile(os.path.join(directory,f))):
                file_list.append(f)
        #print(file_list)
        file_list.sort(key=natural_keys)
        return file_list
    else:
        print("There is no such directory!!!")
        
list_files = get_all_files("data/optional_training")
#print list_files

# %%
def optional_res(optional_file):
    D = {}
    f = open(optional_file,'r')
    for line in f:
            words = line.split()
            D[words[0]] = words[1]
            
    return D

D = optional_res("data/optional_project_train_scores.txt")
#print D
print max(D.values())
print min(D.values())#10
# Out:
# 0.828282828283
# -0.000315547731673

# %%
stop_data = set(['', 'secondly', 'all', 'consider', 'whoever', 'four', 'edu', 'go', 'causes', 'seemed', 'rd', 'certainly', 'vs', 'to', 'asking', 'th', 'under', 'sorry', "a's", 'sent', '@', 'far', 'every', 'yourselves', '`', "we'll", 'went', 'did', 'forth', "they've", 'try', 'p', "it'll", "i'll", 'says', "you'd", 'yourself', 'likely', 'further', 'quite', 'even', 'what', 'appear', 'brief', 'goes', 'sup', 'new', ';', 'ever', "c'mon", 'whose', 'respectively', 'never', 'here', 'let', 'others', "hadn't", 'along', "aren't", 'k', 'allows', "i'd", 'howbeit', 'usually', 'whereupon', "i'm", 'changes', 'thats', 'hither', 'via', 'followed', 'merely', 'while', 'viz', 'everybody', 'use', 'from', 'would', 'contains', 'two', 'next', 'few', 'therefore', 'taken', 'themselves', 'thru', 'tell', 'more', '``', 'knows', 'becomes', 'hereby', 'herein', "ain't", 'particular', 'known', 'must', 'me', 'none', 'f', 'this', 'oh', 'anywhere', 'nine', 'can', 'theirs', 'following', 'my', 'example', 'indicated', "didn't", 'indicates', 'something', 'want', 'needs', 'rather', 'meanwhile', 'how', 'instead', 'okay', 'tried', 'may', 'after', 'different', 'hereupon', 'such', 'a', 'third', 'whenever', 'maybe', 'appreciate', 'q', ')', 'ones', 'so', 'specifying', 'allow', 'keeps', "that's", 'six', 'help', "don't", 'indeed', 'over', 'mainly', 'soon', 'course', 'through', 'looks', 'still', 'its', 'before', 'thank', "he's", 'selves', 'inward', ',', 'actually', 'better', 'whether', 'willing', 'thanx', 'ours', 'might', '<', "haven't", 'then', 'non', 'someone', 'somebody', 'thereby', "you've", 'they', 'not', 'now', 'nor', 'several', 'hereafter', 'always', 'reasonably', 'whither', 'l', 'each', 'entirely', "isn't", 'mean', 'everyone', 'doing', 'eg', 'ex', 'our', 'beyond', 'out', 'them', 'furthermore', 'since', 'looking', 're', 'seriously', "shouldn't", "they'll", 'got', 'cause', 'thereupon', "you're", 'given', 'like', 'que', 'besides', 'x', 'ask', 'anyhow', 'g', 'could', 'tries', 'keep', 'w', 'ltd', 'hence', 'onto', 'think', 'first', 'already', 'seeming', 'thereafter', 'one', 'done', 'another', 'awfully', "doesn't", 'little', 'their', 'accordingly', 'least', 'name', 'anyone', 'indicate', 'too', 'gives', 'mostly', 'behind', 'nobody', 'took', 'immediate', 'regards', 'somewhat', 'off', 'believe', 'herself', 'than', "here's", 'b', 'unfortunately', 'gotten', 'second', 'i', 'r', 'were', 'toward', 'are', 'and', 'beforehand', 'say', 'unlikely', 'have', 'need', 'seen', 'seem', 'saw', 'any', 'relatively', 'zero', 'thoroughly', 'latter', 'that', 'downwards', 'aside', 'thorough', 'also', 'take', 'which', 'exactly', 'unless', 'shall', 'who', "where's", 'most', 'eight', 'but', 'nothing', 'why', 'sub', 'especially', 'noone', 'later', 'm', 'yours', "you'll", 'definitely', 'normally', 'came', 'saying', 'particularly', 'anyway', 'fifth', '(', 'outside', 'should', 'only', 'going', 'specify', 'do', 'his', 'above', 'get', 'between', 'overall', 'truly', "they'd", 'cannot', 'nearly', 'despite', 'during', 'him', 'regarding', 'qv', 'h', 'twice', 'she', 'contain', "won't", 'where', 'thanks', 'ignored', 'up', 'namely', 'anyways', 'best', 'wonder', 'said', 'away', 'currently', 'please', 'enough', "there's", 'various', 'hopefully', 'probably', 'neither', 'across', 'available', 'we', 'useful', 'however', 'come', 'both', 'c', 'last', 'many', "wouldn't", 'thence', 'according', 'against', 'etc', 's', 'became', 'com', "can't", 'otherwise', 'among', 'liked', 'co', 'afterwards', 'seems', 'whatever', 'alone', "couldn't", 'moreover', 'throughout', 'considering', 'sensible', 'described', "it's", 'three', 'been', '.', 'whom', 'much', 'wherein', 'hardly', "it'd", '>', 'wants', 'corresponding', 'latterly', 'concerning', 'else', 'hers', 'former', 'those', 'myself', 'novel', 'look', 'these', 'value', 'n', 'will', 'near', 'theres', 'seven', 'whereafter', 'almost', 'wherever', 'is', 'thus', 'it', 'cant', 'itself', 'in', 'ie', 'y', 'if', 'containing', 'perhaps', 'insofar', 'same', 'clearly', 'beside', 'when', 'gets', "weren't", 'used', 'see', 'somewhere', 'upon', 'uses', 'kept', 'whereby', 'nevertheless', 'whole', 'well', 'anybody', 'obviously', 'without', 'comes', 'very', 'the', 'self', 'lest', 'just', 'less', 'being', 'able', 'presumably', 'greetings', 'regardless', 'yes', 'yet', 'unto', '$', "we've", 'had', 'except', 'has', 'ought', "t's", 'around', "who's", 'possible', 'five', 'know', 'using', 'apart', 'necessary', 'd', 'follows', 'either', 'become', 'towards', 'therein', 'because', 'old', 'often', 'some', 'somehow', 'sure', 'specified', 'ourselves', 'happens', 'for', 'though', 'per', 'everything', 'does', 'provides', 'tends', 't', 'be', 'nowhere', 'although', 'by', 'on', 'about', 'ok', 'anything', 'getting', 'of', 'v', 'o', 'whence', 'plus', 'consequently', 'or', 'seeing', 'own', 'formerly', 'into', 'within', 'down', 'appropriate', 'right', "c's", 'your', 'her', 'there', 'inasmuch', 'inner', 'way', ':', 'was', 'himself', 'elsewhere', "i've", 'becoming', 'amongst', 'hi', 'trying', 'with', 'he', "they're", "wasn't", 'wish', 'j', "hasn't", 'us', 'until', 'placed', 'below', 'un', 'z', "we'd", 'gone', 'sometimes', 'associated', 'certain', 'am', 'an', 'as', 'sometime', 'at', 'et', 'inc', 'again', 'uucp', '%', 'no', 'whereas', 'nd', 'lately', 'other', 'you', 'really', "what's", "'s", 'welcome', "let's", 'serious', 'e', 'together', 'having', 'u', "we're", 'everywhere', 'hello', 'once'])
# Out:
# <type 'set'>

# %%
dale_data = set(['pardon', 'yellow', 'hitch', 'four', 'woods', 'sleep', 'captain', 'hate', 'yonder', 'lace', 'trolley', 'whose', 'electricity', 'swan', 'tickle', 'swat', 'teaspoon', 'under', 'lord', 'sorry', 'chill', 'worth', 'tame', 'blanket', 'rise', 'vase', 'shoot', 'smack', 'every', 'govern', 'fireplace', 'school', 'baking', 'prize', 'buttonhole', 'clothes', 'enjoy', 'chew', 'bicycle', 'quilt', 'clover', 'bacon', 'direct', 'horn', 'nail', 'likely', 'street', 'summer', 'writing', 'shining', 'blue', 'hide', 'pace', 'thunder', 'cooking', 'near', 'liberty', 'sung', 'aged ', 'new', 'net', 'ever', 'told', 'hero', 'men', 'drew', 'herd', 'met', 'mew', 'bookcase', 'china', 'hers', 'path', "aren't", 'dry', 'daughter', 'study', 'cupful', 'robin', 'swam', 'far-off', 'smoke', 'lonesome', 'golden', 'divide', 'straw', 'godmother', 'strap', 'brought', 'ninety', 'glance', 'overhear', 'ore', 'spoke', 'would', 'army', 'hospital', 'June', 'insult', 'call', 'until', 'spike', 'blueberry', 'calf', 'breathe', 'holy', 'hurt', 'warn', 'glass', 'wildcat', 'warm', 'smile', 'hole', 'hold', 'blindfold', 'must', 'me', 'join', 'room', 'shame', 'work', 'gasoline', 'worm', 'candlestick', 'movies', 'rim', 'elbow', 'my', 'route', 'shook', 'thirsty', 
', 'fill', 'ball', 'slave', 'drink', 'upon', 'beast', 'absent ', 'grandstand', 'painful', 'dust', 'overalls', 'collar', 'single', 'off', 'center', 'fully', 'weapon', 'well', 'thought', 'drawing', 'cried', 'flesh', 'boot', 'wren', 'loaf', 'front', 'Sunday', 'glue', 'lettuce', 'happiness', 'flashlight', 'web', 'wee', 'tight', 'Friday', 'sky', 'gum', 'bench', 'other', 'crack', 'ought', 'ski', 'kick', 'oar', 'knob', 'sick', 'government', "who's", 'haul', 'five', 'know', 'knot', 'desk', 'tick', "who'd", 'name', 'loss', 'helpful', 'lost', 'sofa', 'candy', 'garage', 'sissy', 'lose', 'become', 'soft', 'page', 'heel', 'shed', 'because', 'tumble', 'village', 'junk', 'hail', 'hair', 'alike ', 'proper', 'home', 'liking', "shan't", 'leaf', 'lead', 'broad', 'kettle', 'lean', 'shone', 'leap', 'campfire', 'fisherman', 'leader', 'season', 'pepper', 'hose', 'obey', 'pear', 'mitt', 'peas', 'host', 'stormy', 'paste', 'swept', 'noisy', 'throne', 'about', 'getting', 'column', 'freedom', 'biscuit', 'flake', 'swear', 'toadstool', 'blackness', 'cranberry', 'tongue', 'upward', 'swimming', 'owl', 'own', 'owe', 'payment', 'tag', 'socks', 'cocoa', 'guard', 'weather', 'promise', 'brush', 'custard', 'rowboat', 'rejoice', 'scrap', 'whom', 'buckle', 'soil', 'watchman', 'visitor', 'November', 'ivory', 'buy', 'north', 'catsup', 'bus', 'but', 'bun', 'ho', 'bum', 'good-bye', 'ha', 'eat', 'bud', 'he', 'count', 'misty', 'made', 'wise', 'glory', 'dangerous', 'smooth', 'flip', 'nightgown', 'pansy', 'record', 'carriage', 'stories', 'woke', 'cake', 'piece', 'pin', 'mask', 'circus', 'pie', 'pig', 'inn', 'goodness', 'ink', 'partly', 'pit', 'happen', 'squirrel', 'pussycat', 'accident ', 'coffeepot', 'book', 'boom', 'branch', 'out', "you're", 'dresser', 'February', 'repeat', 'star', 'again ', 'bundle', 'stay', 'April', 'chance', 'squeak', 'cliff', 'baker', 'rule', 'pupil', 'misspell', 'lives', 'yell', 'sash'])

# %%
import string

def syllable(word):
    vowels = 'aeiouy'
    count = 0
    
    if word[0] in vowels:
        count +=1        
    if word[len(word)-1] =='e':
        count -= 1
    if word.endswith('le'):
        count+=1
        
    for i,item in enumerate(word):
        if(i == 0):
            continue
        if word[i] in vowels and word[i-1] not in vowels:
            count +=1
            
    if count == 0:
        count +=1
    return count

print syllable("Bobobe!")
# Out:
# 2

# %%
import nltk
import re

text = word_tokenize("And you've for something completely different")
nltk.pos_tag(text)
# Out:
# [('And', 'CC'),
#  ('you', 'PRP'),
#  ("'ve", 'VBP'),
#  ('for', 'IN'),
#  ('something', 'NN'),
#  ('completely', 'RB'),
#  ('different', 'JJ')]

# %%
from nltk import sent_tokenize,word_tokenize
import subprocess
from collections import defaultdict, Counter
import os
import math
       
class UnigramModel(object):
    def __init__(self,freqmodel):
        self.word_counts = {}
        f = open(freqmodel, 'r')
        for line in f:
            words = line.rsplit(",",1)
            #line.split("\t")
            self.word_counts[words[0]] = int(words[1].strip())
        
        total = sum(self.word_counts.values())
        self.word_probs={}
        
        for word in self.word_counts:
            self.word_probs[word] = self.word_counts[word]/float(total)

    
    def logprob(self,target_word):
        if(target_word in self.word_probs):
            return math.log(self.word_probs[target_word],2)
        else:
            return float("-inf")

def get_good_turing(frequency_model):
    '''Param: frequency model is the absolute path of a frequency model ﬁle corresponding to the
    unigram model.
    Return: A dict mapping an int to a float.'''
    Dict = defaultdict(int)
    Nvalues = defaultdict(int)
    New_Dict = defaultdict(float)
    
    f = open(frequency_model,'r')
    for line in f:
        word = line.rsplit(",",1)
        Dict[word[0]] = int(word[1].strip())
    
    V = len(Dict)
    Nvalues[0] = 1
    for key,value in Dict.items():
        Nvalues[value]+=1
        
    for r in range(6):
        if(Nvalues[r]!=0):
            r_dash = ((r+1)*Nvalues[r+1])/float(Nvalues[r])
        New_Dict[r] = r_dash
        
    f.close()
    
    return New_Dict

def get_type_token_ratio(counts_file):
    Dict = defaultdict(int)
    
    f = open(counts_file,'r')
    for line in f:
        word = line.rsplit(",",1)
        #line.split("\t")
        Dict[word[0]] = int(word[1].strip())
    
    type_str = len(Dict)
    token_str = sum(Dict.values())
    
    return type_str/float(token_str)

def get_entropy(unigram_counts_file):
        Dict = defaultdict(int)    
        f = open(unigram_counts_file,'r')
        for line in f:
            word = line.rsplit(",",1)
            #line.split("\t")
            Dict[word[0]] = int(word[1].strip())
        total = 0
        total_denom = float(sum(Dict.values()))
        for word in Dict:
            prob = Dict[word]/total_denom
            total+= prob*(math.log(prob,2))
        
        return(total*(-1.0))

class BigramModel(object):
    def __init__(self,trainfiles):
        self.Dict = defaultdict(int)
        self.uniDict = defaultdict(int)
        Final = []
        
        for file_name in trainfiles:
            F = open(file_name, 'r')
            s_sent = sent_tokenize(F.read().decode("utf-8"))
                        
            for each in s_sent:
                Final.append(["<s>"]+word_tokenize(each)+["</s>"])
            F.close()
                
        self.uniDict = Counter([item for sublist in Final for item in sublist])
        self.uniDict["<UNK>"] = 0

        for key,value in self.uniDict.items():
            if(value == 1):
                self.uniDict["<UNK>"]+=1
                del self.uniDict[key]            

        for each in Final:
            for i in xrange(len(each)-1):
                if(each[i] not in self.uniDict):
                    each[i] = "<UNK>"
                if(each[i+1] not in self.uniDict):
                    each[i+1] = "<UNK>"
                self.Dict[(each[i],each[i+1])]+=1

    def logprob(self, prior_context, target_word):
        if(prior_context not in self.uniDict):
            prior_context = "<UNK>"
            
        if(target_word not in self.uniDict):
            target_word = "<UNK>"
        k = 0.25
        return math.log((self.Dict[(prior_context,target_word)]+k)/
                        (float(self.uniDict[prior_context])+(k*len(self.uniDict))),2)

def srilm_preprocess(raw_text,temp_file):
        sent_tokens = sent_tokenize(raw_text.decode("utf-8"))
        f = open(temp_file, 'wb')
        for line in sent_tokens:
            line = line+"\n"
            f.write(line.encode("utf-8"))

        f.close()

def srilm_bigram_models(input_file, output_dir):
    f = open(input_file,'r')
    raw_text = f.read().decode("utf-8")
    temp_file = "temp_file.txt"
    srilm_preprocess(raw_text, temp_file)

    model_file = output_dir+os.path.basename(input_file)+".uni.lm"
    subprocess.call(["/home1/c/cis530/srilm/ngram-count", "-text",temp_file,"-lm",model_file,"-order","1","-addsmooth","0.25"])

    model_file = output_dir+os.path.basename(input_file)+".bi.lm"
    subprocess.call(["/home1/c/cis530/srilm/ngram-count", "-text",temp_file,"-lm",model_file,"-order","2","-addsmooth","0.25"])

    model_file = output_dir+os.path.basename(input_file)+".bi.kn.lm"
    subprocess.call(["/home1/c/cis530/srilm/ngram-count", "-text",temp_file,"-lm",model_file,"-order","2","-kndiscount"])

def srilm_ppl(model_file, raw_text):
    temp_file = "temp_file2.txt"
    srilm_preprocess(raw_text, temp_file)
    subprocess.call(["/home1/c/cis530/srilm/ngram","-lm",model_file,"-ppl",temp_file])

# %%
def get_stop(stop_file):
    f = open(stop_file,'r')
    stop_data = set(f.read().split('\n'))
    #print stop_data
    f.close()
    return stop_data

stop_file = "/home/swathi/Jupyter/CL_HW4/data/stopwords.txt"#"/home1/c/cis530/hw4/stopwords.txt"
stop_data = get_stop(stop_file)

# %%
hard = "NO is a pleiotropic signaling molecule and has an important role in cognition and emotion. In the brain, NO is produced by neuronal nitric oxide synthase (NOS-I, encoded by NOS1) coupled to the NMDA receptor via PDZ interactions; this protein-protein interaction is disrupted upon binding of NOS1 adapter protein (encoded by NOS1AP) to NOS-I. As both NOS1 and NOS1AP were associated with schizophrenia, we here investigated these genes in greater detail by genotyping new samples and conducting a meta-analysis of our own and published data. In doing so, we confirmed association of both genes with schizophrenia and found evidence for their interaction in increasing risk towards disease. Our strongest finding was the NOS1 promoter SNP rs41279104, yielding an odds ratio of 1.29 in the meta-analysis. As findings from heterologous cell systems have suggested that the risk allele decreases gene expression, we studied the effect of the variant on NOS1 expression in human post-mortem brain samples and found that the risk allele significantly decreases expression of NOS1 in the prefrontal cortex. Bioinformatic analyses suggest that this might be due the replacement of six transcription factor binding sites by two new binding sites as a consequence of proxy SNPs. Taken together, our data argue that genetic variance in NOS1 resulting in lower prefrontal brain expression of this gene contributes to schizophrenia liability, and that NOS1 interacts with NOS1AP in doing so. The NOS1-NOS1AP PDZ interface may thus well constitute a novel target for small molecules in at least some forms of schizophrenia."

print hard
# Out:
# NO is a pleiotropic signaling molecule and has an important role in cognition and emotion. In the brain, NO is produced by neuronal nitric oxide synthase (NOS-I, encoded by NOS1) coupled to the NMDA receptor via PDZ interactions; this protein-protein interaction is disrupted upon binding of NOS1 adapter protein (encoded by NOS1AP) to NOS-I. As both NOS1 and NOS1AP were associated with schizophrenia, we here investigated these genes in greater detail by genotyping new samples and conducting a meta-analysis of our own and published data. In doing so, we confirmed association of both genes with schizophrenia and found evidence for their interaction in increasing risk towards disease. Our strongest finding was the NOS1 promoter SNP rs41279104, yielding an odds ratio of 1.29 in the meta-analysis. As findings from heterologous cell systems have suggested that the risk allele decreases gene expression, we studied the effect of the variant on NOS1 expression in human post-mortem brain sample
# ...
